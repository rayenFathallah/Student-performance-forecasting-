# %% [markdown]
# # Student performance forcasting

# %% [markdown]
# ## Abstract
# #just making a test here
# Determining whether a student performance can be predicted, hence improved, based on different factors that play a role in a student educational life. The main aim of this project, Is to apply machine learning techniques that can put light on the most important factors that impact a student performance, In order to gain a better understanding of learners.

# %% [markdown]
# ## Motivation
# Deciding whether a student will fail or pass is a challenging task. Administators, teachers, and essentially parents, deeply want to know whether a student will fail, or succeed, In order to make good decisions. Based on several factors like age, freetime, activities, parents job etc ... We will try to get a clearer idea on how all these factors influence the student grades.
# In order to achieve that, we will start with an existing data and use supervised learning techniques In order to predict the grades of a student.
# The main focus will be on interpreting the importance of each factor in a student's life.

# %% [markdown]
# ## Dataset
# <li> school - student's school (binary: 'GP' - Gabriel Pereira or 'MS' - Mousinho da Silveira) </li>
# <li> sex - student's sex (binary: 'F' - female or 'M' - male)
# <li> age - student's age (numeric: from 15 to 22)</li>
# <li> address - student's home address type (binary: 'U' - urban or 'R' - rural)</li>
# <li>famsize - family size (binary: 'LE3' - less or equal to 3 or 'GT3' - greater than 3)</li>
# <li>Pstatus - parent's cohabitation status (binary: 'T' - living together or 'A' - apart)</li>
# <li> Medu - mother's education (numeric: 0 - none, 1 - primary education (4th grade), 2 - 5th to 9th grade, 3 - secondary education or 4 -  higher education)</li>
# <li> Fedu - father's education (numeric: 0 - none, 1 - primary education (4th grade), 2 - 5th to 9th grade, 3 - secondary education or 4 - higher education)</li>
# <li> Mjob - mother's job (nominal: 'teacher', 'health' care related, civil 'services' (e.g. administrative or police), 'at_home' or 'other')</li>
# <li> Fjob - father's job (nominal: 'teacher', 'health' care related, civil 'services' (e.g. administrative or police), 'at_home' or 'other')</li>
# <li> reason - reason to choose this school (nominal: close to 'home', school 'reputation', 'course' preference or 'other')</li>
# <li> guardian - student's guardian (nominal: 'mother', 'father' or 'other')</li>
# <li>traveltime - home to school travel time (numeric: 1 -  less than 15 min., 2 - 15 to 30 min., 3 - 30 min. to 1 hour, or 4 - >1 hour)</li>
# <li>studytime - weekly study time (numeric: 1 - less than 2 hours, 2 - 2 to 5 hours, 3 - 5 to 10 hours, or 4 - more than 10 hours)</li>
# <li>failures - number of past class failures (numeric: n if n>=1 and n less than 3, else 4)</li>
# <li> schoolsup - extra educational support (binary: yes or no)</li>
# <li> famsup - family educational support (binary: yes or no)</li>
# <li> paid - extra paid classes within the course subject (Math or Portuguese) (binary: yes or no)</li>
# <li> activities - extra-curricular activities (binary: yes or no)</li>
# <li> nursery - attended nursery school (binary: yes or no)</li>
# <li> higher - wants to take higher education (binary: yes or no)</li>
# <li> internet - Internet access at home (binary: yes or no)</li>
# <li> romantic - with a romantic relationship (binary: yes or no)</li>
# <li> famrel - quality of family relationships (numeric: from 1 - very bad to 5 - excellent)</li>
# <li> freetime - free time after school (numeric: from 1 - very low to 5 - very high)</li>
# <li> goout - going out with friends (numeric: from 1 - very low to 5 - very high)</li>
# <li>Dalc - workday alcohol consumption (numeric: from 1 - very low to 5 - very high)</li>
# <li> Walc - weekend alcohol consumption (numeric: from 1 - very low to 5 - very high)</li>
# <li> health - current health status (numeric: from 1 - very bad to 5 - very good)</li>
# <li> absences - number of school absences (numeric: from 0 to 93)</li>
# <b>target variables :<br></b>
# <li> G1 - first period grade (numeric: from 0 to 20) </li>
#     <li> G2 - second period grade (numeric: from 0 to 20)</li>
#     <li> G3 - final grade (numeric: from 0 to 20, output target)</li>

# %% [markdown]
# <b> Importing important libraries :

# %%
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt 
import numpy as np 
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score,mean_squared_error
from scipy import stats as stats 
from sklearn.preprocessing import LabelEncoder

# %%
df_math = pd.read_csv("/content/student-por.csv",sep=";")

# %% [markdown]
# <b> Merging the two datasets ( portugese grades and maths grades)

# %%
df_math.shape
# Out:
# (649, 33)

# %%
df_math
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
print(f"Maths dataframe shape is : {df_math.shape}")
# Out:
# Maths dataframe shape is : (649, 33)

# %%
df_math.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean    16.744222    2.514638    2.306626    1.568567    1.930663    0.221880
# std      1.218138    1.134552    1.099931    0.748660    0.829510    0.593235
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    1.000000    1.000000    1.000000    0.000000
# 50%     17.000000    2.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean     3.930663    3.180277    3.184900    1.502311    2.280431    3.536210
# ...

# %% [markdown]
# ### We first have to specify one target value, for this case, we get the average of the 3 scores.

# %%
df_math['Final_score']= (df_math['G1']+df_math['G2']+df_math['G3'])/3

# %%
df_math.isna().sum()
# Out:
# school         0
# sex            0
# age            0
# address        0
# famsize        0
# Pstatus        0
# Medu           0
# Fedu           0
# Mjob           0
# Fjob           0
# reason         0
# guardian       0
# traveltime     0
# studytime      0
# failures       0
# schoolsup      0
# famsup         0
# paid           0
# activities     0
# nursery        0
# higher         0
# internet       0
# romantic       0
# famrel         0
# freetime       0
# goout          0
# Dalc           0
# Walc           0
# health         0
# absences       0
# G1             0
# G2             0
# G3             0
# Final_score    0
# dtype: int64

# %%
df_math.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 34 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   school       649 non-null    object
#  1   sex          649 non-null    object
#  2   age          649 non-null    int64
#  3   address      649 non-null    object
#  4   famsize      649 non-null    object
#  5   Pstatus      649 non-null    object
#  6   Medu         649 non-null    int64
#  7   Fedu         649 non-null    int64
#  8   Mjob         649 non-null    object
#  9   Fjob         649 non-null    object
#  10  reason       649 non-null    object
#  11  guardian     649 non-null    object
#  12  traveltime   649 non-null    int64
#  13  studytime    649 non-null    int64
#  14  failures     649 non-null    int64
#  15  schoolsup    649 non-null    object
#  16  famsup       649 non-null    object
#  17  paid         649 non-null    object
# ...

# %%
df_math.duplicated().sum()
# Out:
# 0

# %%
numeric_df = df_math.select_dtypes(int).columns
numeric_df
# Out:
# Index(['age', 'Medu', 'Fedu', 'traveltime', 'studytime', 'failures', 'famrel',
#        'freetime', 'goout', 'Dalc', 'Walc', 'health', 'absences', 'G1', 'G2',
#        'G3'],
#       dtype='object')

# %%
def viz_distribution(data,col) :
    fig,ax = plt.subplots(nrows=1,ncols=2,figsize=(15,6))
    sns.distplot(x=data[col],ax=ax[0])
    stats.probplot(data[col],dist='norm',plot=plt)
    plt.title(col)

def detecting_outliers(data,col): 
    fig,ax = plt.subplots(nrows=1,ncols=2,figsize=(15,6))
    data.plot.scatter(x=col,y='Final_score',ax=ax[0])
    sns.boxplot(data=data,x=col,ax=ax[1])
    plt.title(col)

# %%
for elem in numeric_df : 
    detecting_outliers(df_math,elem)
# Out:
# WARNING:matplotlib.axes._axes:*c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# WARNING:matplotlib.axes._axes:*c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# ...

# %% [markdown]
# Most of the features are categorical, so It won't be easy to detect outliers, so we will just remove the very rare values that we judge not valuable for our case.
# In our situation, absences over 45 hour doesn't quitely look normal, as well as being older than 21 years old for a high school student.

# %%
df_math=df_math[df_math['age']<=21]
df_math=df_math[df_math['Medu']>=1]
df_math=df_math[df_math['Fedu']>=1]
df_math=df_math[df_math.absences<=45]
df_math=df_math.loc[df_math['G1']>=1]
df_math=df_math.loc[df_math['G2']>=1]

# %%
df_math.shape
# Out:
# (628, 34)

# %% [markdown]
# <b> 9 elements removed

# %%
df_math
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# 5       GP   M   16       U     LE3       T     4     3  services     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %% [markdown]
# ## EDA of our dataset

# %%
data2=df_math.copy()

# %%
def multi_coll_vis(data,col):
    plt.figure(figsize=(10,5))

    plt.title(f"Grades based on {col}" )
    sns.regplot(x=col, y="G1", data=data, color="blue",label="G1: First Period Grades", 
                scatter= False, ci= None)
    sns.regplot(x=col, y="G2", data=data, color="green", label="G2: Second Period Grades",
               scatter= False, ci= None)
    sns.regplot(x=col, y="G3", data=data, color="orange", label="G3: Final Period Grades",
                scatter= False, ci= None)
    plt.xlabel(col)
    plt.ylabel("Grades")

    plt.legend(loc="upper left")
    plt.show()

# %% [markdown]
# ### 1- Parents Education

# %%
viz_distribution(data2,'Fedu')

# %%
viz_distribution(data2,'Medu')

# %%
multi_coll_vis(data2,'Fedu')

# %% [markdown]
# It is quite clear that parents education play a big role in a student's grades. The better education the parents have, the better grades a student is more likely to have.

# %% [markdown]
# ### 2- Age

# %%
multi_coll_vis(data2,'age')

# %%
data2.groupby(['age'])['Final_score'].sum().plot(kind = 'bar',figsize=(10,5))

# %% [markdown]
# ### 3- Travel Time

# %%
viz_distribution(data2,'traveltime')

# %%
multi_coll_vis(data2,'traveltime')

# %%
data2.groupby(['traveltime'])['Final_score'].sum().plot(kind = 'bar',figsize=(10,5))
data2["traveltime_log"]=np.log1p(data2['traveltime'])

# %% [markdown]
# The longer the road is, the worse the grades are

# %% [markdown]
# ### 4- Study time

# %%
viz_distribution(data2,'studytime')

# %%
multi_coll_vis(data2,'studytime')

# %%
data2.groupby(['studytime'])['Final_score'].sum().plot(kind = 'bar',figsize=(10,5))

# %% [markdown]
# Obviously, the more time a student sacrifices to study, the better the grades he gets.

# %% [markdown]
# ### 5- Failures

# %%
viz_distribution(data2,'failures')

# %%
multi_coll_vis(data2,'failures')

# %%
data2.groupby(['failures'])['Final_score'].sum().plot(kind = 'bar',figsize=(10,5))

# %% [markdown]
# ### 6 - Family relationship

# %%
viz_distribution(data2,'famrel')

# %%
multi_coll_vis(data2,'famrel')

# %%
data2.groupby(['famrel'])['Final_score'].sum().plot(kind = 'bar',figsize=(10,5))

# %% [markdown]
# Family relationship doesn't provide relevant insights, since each time, it affects the output variable differently. That's why we won't be considering it as an important feature in this problem.

# %% [markdown]
# ### 7- Free time

# %%
viz_distribution(data2,'freetime')

# %%
multi_coll_vis(data2,'freetime')

# %% [markdown]
# ### 8 - Health

# %%
viz_distribution(data2,'health')

# %%
multi_coll_vis(data2,'health')

# %%
viz_distribution(data2,'absences')

# %%
multi_coll_vis(data2,'absences')

# %% [markdown]
# ## II - Skewness and correlations

# %%
def transformation_vis(data,norm,changed): 
    fig,ax = plt.subplots(nrows=1,ncols=2,figsize=(15,6))
    sns.distplot(data[norm],ax=ax[0])
    sns.distplot(data[changed],ax=ax[1])
    plt.title("Visualizing changed after transformation")

# %%
plt.figure(figsize=(20,10))
sns.heatmap(data2.corr(),annot=True)

# %%
skewed_values = data2.skew()
skewed_cols = skewed_values[abs(skewed_values>0.5)].index
skewed_cols
# Out:
# Index(['traveltime', 'studytime', 'failures', 'Dalc', 'Walc', 'absences',
#        'traveltime_log'],
#       dtype='object')

# %% [markdown]
# For the highly skewed features, we will be applying some transformations in order to minimize this skewness and get closer to a normal distribution.

# %%
data2['traveltime_log']=np.log1p(data2['traveltime_log'])

# %%
viz_distribution(data2,'traveltime_log')

# %%
data2.corr()["traveltime_log"]
# Out:
# age               0.056267
# Medu             -0.262268
# Fedu             -0.209655
# traveltime        0.981958
# studytime        -0.075683
# failures          0.117752
# famrel           -0.029381
# freetime         -0.011235
# goout             0.038156
# Dalc              0.091627
# Walc              0.053769
# health           -0.046737
# absences          0.005201
# G1               -0.165587
# G2               -0.159664
# G3               -0.137788
# Final_score      -0.160301
# traveltime_log    1.000000
# Name: traveltime_log, dtype: float64

# %%
data2.drop('traveltime',axis=1)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# 5       GP   M   16       U     LE3       T     4     3  services     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
data2['absences_log']=np.log1p(data2['absences'])

# %%
viz_distribution(data2,'absences_log')

# %%
transformation_vis(data2,'absences','absences_log')

# %% [markdown]
# Since we only have absences as continious variables, we will only standardize it.

# %%
col_names = ['absences_log']
features = data2[col_names]
scaler = StandardScaler().fit(features.values)
features = scaler.transform(features.values)
data2['std_abs']=np.concatenate(features, axis=0 )
transformation_vis(data2,'absences','std_abs')

# %% [markdown]
# No big changed after transformation

# %% [markdown]
# Since Medu and Fedu are highly correlated, we will keep only one  which is "Medu" since it is more correlated with our output than Fedu.

# %%
data2.drop('Fedu',axis=1)
# Out:
#     school sex  age address famsize Pstatus  Medu      Mjob      Fjob  \
# 1       GP   F   17       U     GT3       T     1   at_home     other
# 2       GP   F   15       U     LE3       T     1   at_home     other
# 3       GP   F   15       U     GT3       T     4    health  services
# 4       GP   F   16       U     GT3       T     3     other     other
# 5       GP   M   16       U     LE3       T     4  services     other
# ..     ...  ..  ...     ...     ...     ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2  services     other
# 645     MS   F   18       U     LE3       T     3   teacher  services
# 646     MS   F   18       U     GT3       T     1     other     other
# 647     MS   M   17       U     LE3       T     3  services  services
# 648     MS   M   18       R     LE3       T     3  services     other
#
#          reason  ... Walc  health  absences  G1  G2  G3 Final_score  \
# ...

# %% [markdown]
# We apply The same thing for Walc and Dalc.

# %%
data2.drop('Dalc',axis=1)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# 5       GP   M   16       U     LE3       T     4     3  services     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %% [markdown]
# ### III Encoding categorical data

# %%
cat_cols = data2.select_dtypes(object).columns
cat_cols
# Out:
# Index(['school', 'sex', 'address', 'famsize', 'Pstatus', 'Mjob', 'Fjob',
#        'reason', 'guardian', 'schoolsup', 'famsup', 'paid', 'activities',
#        'nursery', 'higher', 'internet', 'romantic'],
#       dtype='object')

# %%
pd.get_dummies(data=data2,columns=["school",'Pstatus',"Mjob",'Fjob','reason','guardian'],drop_first=True)
# Out:
#     sex  age address famsize  Medu  Fedu  traveltime  studytime  failures  \
# 1     F   17       U     GT3     1     1           1          2         0
# 2     F   15       U     LE3     1     1           1          2         0
# 3     F   15       U     GT3     4     2           1          3         0
# 4     F   16       U     GT3     3     3           1          2         0
# 5     M   16       U     LE3     4     3           1          2         0
# ..   ..  ...     ...     ...   ...   ...         ...        ...       ...
# 644   F   19       R     GT3     2     3           1          3         1
# 645   F   18       U     LE3     3     1           1          2         0
# 646   F   18       U     GT3     1     1           2          2         0
# 647   M   17       U     LE3     3     1           2          1         0
# 648   M   18       R     LE3     3     2           3          1         0
#
#     schoolsup  ... Mjob_teacher Fjob_health Fjob_other Fjob_services  \
# ...

# %%
data3=pd.get_dummies(data=data2,columns=["school",'Pstatus',"Mjob",'Fjob','reason','guardian'],drop_first=True)
data3
# Out:
#     sex  age address famsize  Medu  Fedu  traveltime  studytime  failures  \
# 1     F   17       U     GT3     1     1           1          2         0
# 2     F   15       U     LE3     1     1           1          2         0
# 3     F   15       U     GT3     4     2           1          3         0
# 4     F   16       U     GT3     3     3           1          2         0
# 5     M   16       U     LE3     4     3           1          2         0
# ..   ..  ...     ...     ...   ...   ...         ...        ...       ...
# 644   F   19       R     GT3     2     3           1          3         1
# 645   F   18       U     LE3     3     1           1          2         0
# 646   F   18       U     GT3     1     1           2          2         0
# 647   M   17       U     LE3     3     1           2          1         0
# 648   M   18       R     LE3     3     2           3          1         0
#
#     schoolsup  ... Mjob_teacher Fjob_health Fjob_other Fjob_services  \
# ...

# %%
le= LabelEncoder()
to_le =np.setdiff1d(cat_cols, np.intersect1d(cat_cols,["school",'Pstatus',"Mjob",'Fjob','reason','guardian'] ))
for elem in to_le : 
    data3[elem]= le.fit_transform(data3[elem])
data3
# Out:
#      sex  age  address  famsize  Medu  Fedu  traveltime  studytime  failures  \
# 1      0   17        1        0     1     1           1          2         0
# 2      0   15        1        1     1     1           1          2         0
# 3      0   15        1        0     4     2           1          3         0
# 4      0   16        1        0     3     3           1          2         0
# 5      1   16        1        1     4     3           1          2         0
# ..   ...  ...      ...      ...   ...   ...         ...        ...       ...
# 644    0   19        0        0     2     3           1          3         1
# 645    0   18        1        1     3     1           1          2         0
# 646    0   18        1        0     1     1           2          2         0
# 647    1   17        1        1     3     1           2          1         0
# 648    1   18        0        1     3     2           3          1         0
#
# ...

# %%
data3=data3.drop('Final_score',axis=1)

# %%
data3['score']=np.where(data3['G3']>10,'pass','fail')

# %%
from sklearn.ensemble import GradientBoostingClassifier 
from sklearn.model_selection import train_test_split
Y=data3['score']
X=data3.drop('score',axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split( X, Y, test_size=0.2, random_state=42)

# %%
bosclf=GradientBoostingClassifier (n_estimators=100, max_depth=30, random_state=5).fit(X_train, y_train)
y_pred=bosclf.predict(X_test)

# %%
from sklearn.metrics import accuracy_score 
accuracy_score(y_test, y_pred, normalize=True)
# Out:
# 1.0
